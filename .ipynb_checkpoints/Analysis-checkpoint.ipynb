# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv("data3.csv")
df = df[df["Page"].apply(lambda s: "?" not in s)]

# %%
df.head()
# Out:
#                                   Page          Date       Country  \
# 0                        /wp-login.php  Jun 18, 2021     (not set)
# 1                        /wp-login.php   Jan 7, 2020     (not set)
# 2  /surveys/your-opinion-important-us/  Aug 20, 2020  South Africa
# 3  /surveys/your-opinion-important-us/   Dec 5, 2019  South Africa
# 4  /surveys/your-opinion-important-us/   Apr 6, 2020  South Africa
#
#            User Type Device Category  Users  Time on Page
# 0        New Visitor         desktop     16             0
# 1        New Visitor         desktop     16             0
# 2  Returning Visitor          mobile    129           839
# 3  Returning Visitor          mobile     48          2195
# 4  Returning Visitor          mobile     32             0

# %%
df["User Type"] = pd.get_dummies(df["User Type"], drop_first=True)
df["User Type"] = df["User Type"].apply(lambda x: "Returning" if x == 1 else "New")

# %%
def lookup(date_pd_series, format=None):
    """
    This is an extremely fast approach to datetime parsing.
    For large data, the same dates are often repeated. Rather than
    re-parse these, we store all unique dates, parse them, and
    use a lookup to convert all dates.
    """
    dates = {
        date: pd.to_datetime(date, format=format) for date in date_pd_series.unique()
    }
    return date_pd_series.map(dates)

# %%
df["Date"] = lookup(df["Date"], format="%b %d, %Y")

# %%
df.head()
# Out:
#                                   Page       Date       Country  User Type  \
# 0                        /wp-login.php 2021-06-18     (not set)        New
# 1                        /wp-login.php 2020-01-07     (not set)        New
# 2  /surveys/your-opinion-important-us/ 2020-08-20  South Africa  Returning
# 3  /surveys/your-opinion-important-us/ 2019-12-05  South Africa  Returning
# 4  /surveys/your-opinion-important-us/ 2020-04-06  South Africa  Returning
#
#   Device Category  Users  Time on Page
# 0         desktop     16             0
# 1         desktop     16             0
# 2          mobile    129           839
# 3          mobile     48          2195
# 4          mobile     32             0

# %%
df["Year"] = df["Date"].apply(lambda t: t.year)
df["Month"] = df["Date"].apply(lambda t: t.month)
df["Day"] = df["Date"].apply(lambda t: t.day)

# %%
df.drop("Date", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                   Page       Country  User Type  \
# 0                        /wp-login.php     (not set)        New
# 1                        /wp-login.php     (not set)        New
# 2  /surveys/your-opinion-important-us/  South Africa  Returning
# 3  /surveys/your-opinion-important-us/  South Africa  Returning
# 4  /surveys/your-opinion-important-us/  South Africa  Returning
#
#   Device Category  Users  Time on Page  Year  Month  Day
# 0         desktop     16             0  2021      6   18
# 1         desktop     16             0  2020      1    7
# 2          mobile    129           839  2020      8   20
# 3          mobile     48          2195  2019     12    5
# 4          mobile     32             0  2020      4    6

# %%
topDirs = "surveys sections section search profiles polls documents commenting root".split()

def splitFunc(s):
    x = s.split("/")[1]
    if x == "":
        return "root"
    else:
        return x

df["Page Type"] = df["Page"].apply(splitFunc)

data = df[df["Page Type"].isin(topDirs)]
data = data.reset_index().drop("index", axis=1)

# %%
data.head()
# Out:
#                                   Page       Country  User Type  \
# 0  /surveys/your-opinion-important-us/  South Africa  Returning
# 1  /surveys/your-opinion-important-us/  South Africa  Returning
# 2  /surveys/your-opinion-important-us/  South Africa  Returning
# 3  /surveys/your-opinion-important-us/  South Africa  Returning
# 4  /surveys/your-opinion-important-us/     (not set)  Returning
#
#   Device Category  Users  Time on Page  Year  Month  Day Page Type
# 0          mobile    129           839  2020      8   20   surveys
# 1          mobile     48          2195  2019     12    5   surveys
# 2          mobile     32             0  2020      4    6   surveys
# 3          mobile     32           323  2020      3   29   surveys
# 4          mobile     48          1323  2020      5    6   surveys

# %%
data["Time on Page"] = data["Time on Page"].apply(lambda x: x / 60)
data["Session Length"] = data[["Time on Page", "Users"]].apply(lambda x: x[0] / x[1], axis=1)

# %%
just_the_sections = data[(data["Page Type"] == "section") | (data["Page Type"] == "sections")]

# %%
order = data["Page Type"].value_counts().index

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=30)
g = sns.countplot(data=data, x="Page Type", order=order, hue="User Type")
ax = g.axes
ax.set_yscale("log")
plt.xlabel("Type of Page")
plt.ylabel("Page hits (log scale)")
plt.title("Page Hits by Page Type, User Type")
plt.legend(title="User Type", loc="upper right")

# %%
data.groupby(["User Type","Page Type"]).count()[["Page"]]
# Out:
#                         Page
# User Type Page Type
# New       commenting    1354
#           documents       17
#           polls          211
#           profiles      3224
#           root          5560
#           search         163
#           section      23985
#           sections    131940
#           surveys        736
# Returning commenting    4495
#           documents       42
#           polls          218
#           profiles     17207
#           root          6803
#           section       1476
#           sections    178039
#           surveys       5602

# %%
plt.figure(figsize=(12, 8))
plt.title("Count of Users by User Type")
sns.countplot(data=data, x="User Type")
# Out:
# <AxesSubplot:title={'center':'Count of Users by User Type'}, xlabel='User Type', ylabel='count'>

# %%
data.groupby("User Type").count()["Page"]
# Out:
# User Type
# New          167190
# Returning    213882
# Name: Page, dtype: int64

# %%
plt.figure(figsize=(12, 8))
plt.title("Page Hits by Year, User Type")
sns.countplot(data=data, x="Year", hue="User Type")
# Out:
# <AxesSubplot:title={'center':'Page Hits by Year, User Type'}, xlabel='Year', ylabel='count'>

# %%
# Removing 31 outliers
g = sns.FacetGrid(data[(data["Users"] < 2000) &
                       (data["Users"] > 0) &
                       (data["Session Length"] < 100) &
                       (data["Session Length"] > 0)],
                  row="User Type",
                  col="Year",
                  height=5,
                  aspect=1.2)

g.map(sns.scatterplot, "Users", "Session Length", alpha=0.3)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Session Length vs. Users')
# Out:
# Text(0.5, 0.98, 'Session Length vs. Users')

# %%
g = sns.FacetGrid(data[(data["Users"] >= 2000) | (data["Session Length"] >= 100)],
                  row="User Type",
                  col="Year",
                  height=5,
                  aspect=1.2)

g.map(sns.scatterplot, "Users", "Session Length", alpha=0.3)
# make this a separate plots

# %%
plt.figure(figsize=(12,8))
plt.xticks(range(1, 13), "Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec".split())
plt.title("Session Length by Month, User Type")
plt.ylabel("Average Session Length (mins)")
sns.lineplot(data=data, x="Month", y="Time on Page", hue="User Type", estimator=np.mean, ci=None)
# Out:
# <AxesSubplot:title={'center':'Session Length by Month, User Type'}, xlabel='Month', ylabel='Average Session Length (mins)'>

# %%
plt.figure(figsize=(12,8))
g = sns.catplot(data=data, x="Device Category", col="Year", kind="count")
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle("Page Hits by Year, Device Category")
# Out:
# Text(0.5, 0.98, 'Page Hits by Year, Device Category')

# %%
g = sns.catplot(data=data, x="Device Category", col="Year", hue="User Type", kind="count")
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle('Page Hits by Year, Device Category, User Type')
# Out:
# Text(0.5, 0.98, 'Page Hits by Year, Device Category, User Type')
